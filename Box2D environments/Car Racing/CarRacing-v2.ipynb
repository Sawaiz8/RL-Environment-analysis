# %%
import gymnasium as gym
from stable_baselines3 import A2C, PPO
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os

# %%
env = gym.make("CarRacing-v2", render_mode="human", domain_randomize=True)

# # We get a frame here since we have breakout-v5
# episodes = 1
# for episode in range(episodes+1):
#     obs = env.reset()
#     terminated = False
#     score = 0
#     while not terminated:
#         env.render()
#         action = env.action_space.sample()
#         obs, reward, terminated, truncated, info = env.step(action)
#         score += reward
#         if terminated:
#             observation, info = env.reset()
                    
#     print(f"Episode:{episode} Score:{score}")

# env.close()

# %%
env.observation_space
# Out:
# Box(0, 255, (96, 96, 3), uint8)

# %%
env.action_space 
# [-1 0 0], 1 means that
# Out:
# Box([-1.  0.  0.], 1.0, (3,), float32)

# %%
#Train 438000 steps gets you 400 or 500 reward.
# Environment is solved when we get 900 reward

# %% [markdown]
# # Train Model

# %%
env = gym.make("CarRacing-v2", render_mode="rgb_array")

env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join("training", "logs")

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to training/logs/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 113  |
# |    iterations      | 1    |
# |    time_elapsed    | 18   |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 113        |
# |    iterations           | 2          |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00605878 |
# |    clip_fraction        | 0.0747     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | -0.000718  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0767     |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0072    |
# |    std                  | 0.993      |
# |    value_loss           | 0.498      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 3           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007240307 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.0966      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.261       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00821    |
# |    std                  | 0.987       |
# |    value_loss           | 0.646       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 4           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011507888 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.176       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.979       |
# |    value_loss           | 0.467       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 5           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010916984 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | -0.00539    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0448      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.975       |
# |    value_loss           | 0.467       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 6           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010516953 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.00614     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0568      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.973       |
# |    value_loss           | 0.479       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 7           |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011658529 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.0203      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.174       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.97        |
# |    value_loss           | 0.396       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 8           |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017718092 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0241      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.965       |
# |    value_loss           | 0.329       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 9           |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014585151 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0143      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.96        |
# |    value_loss           | 0.344       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 10          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017592821 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0321      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.94        |
# |    value_loss           | 0.306       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 11          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011836009 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.117       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.932       |
# |    value_loss           | 0.348       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 12          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017274562 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.189       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.919       |
# |    value_loss           | 0.451       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 13         |
# |    time_elapsed         | 239        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01828856 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.98      |
# |    explained_variance   | 0.678      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0752     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0247    |
# |    std                  | 0.911      |
# |    value_loss           | 0.377      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 14          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.025979891 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0257     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.899       |
# |    value_loss           | 0.23        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 15          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021840043 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.885       |
# |    value_loss           | 0.304       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 16          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020815283 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0227      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.878       |
# |    value_loss           | 0.321       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 17          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.022442486 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.869       |
# |    value_loss           | 0.12        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 18         |
# |    time_elapsed         | 333        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02502178 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.81      |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0243    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0286    |
# |    std                  | 0.861      |
# |    value_loss           | 0.164      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 19          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025899697 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0195      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0283     |
# |    std                  | 0.847       |
# |    value_loss           | 0.328       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 20         |
# |    time_elapsed         | 372        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03135572 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.71      |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0839     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0283    |
# |    std                  | 0.833      |
# |    value_loss           | 0.524      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 21         |
# |    time_elapsed         | 390        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.03386606 |
# |    clip_fraction        | 0.296      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.67      |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0321     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0324    |
# |    std                  | 0.825      |
# |    value_loss           | 0.395      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 22          |
# |    time_elapsed         | 410         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.045009956 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0221      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0392     |
# |    std                  | 0.819       |
# |    value_loss           | 0.41        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 23         |
# |    time_elapsed         | 429        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02832676 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.62      |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.149      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0287    |
# |    std                  | 0.813      |
# |    value_loss           | 1.39       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 24          |
# |    time_elapsed         | 447         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.035390913 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.133       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.809       |
# |    value_loss           | 1.19        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 25          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.035566915 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.236       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.805       |
# |    value_loss           | 2.72        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 26         |
# |    time_elapsed         | 484        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.06387071 |
# |    clip_fraction        | 0.384      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.107      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0291    |
# |    std                  | 0.798      |
# |    value_loss           | 0.904      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 27         |
# |    time_elapsed         | 501        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.03483022 |
# |    clip_fraction        | 0.332      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.55      |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.23       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00622   |
# |    std                  | 0.795      |
# |    value_loss           | 4.11       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 28          |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.038572297 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00832    |
# |    std                  | 0.793       |
# |    value_loss           | 4.97        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 29          |
# |    time_elapsed         | 536         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.047592774 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.788       |
# |    value_loss           | 6.46        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 30          |
# |    time_elapsed         | 554         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.038972657 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.914       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00382     |
# |    std                  | 0.786       |
# |    value_loss           | 5.51        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 31         |
# |    time_elapsed         | 571        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.06257093 |
# |    clip_fraction        | 0.406      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.938      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.00198    |
# |    std                  | 0.785      |
# |    value_loss           | 6.16       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 32          |
# |    time_elapsed         | 588         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.057582304 |
# |    clip_fraction        | 0.429       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.000896    |
# |    std                  | 0.784       |
# |    value_loss           | 7.09        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 33         |
# |    time_elapsed         | 606        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.08015989 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.5       |
# |    explained_variance   | 0.91       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.346      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00851   |
# |    std                  | 0.783      |
# |    value_loss           | 3.27       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 34         |
# |    time_elapsed         | 623        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.06762577 |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.49      |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.59       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.00667    |
# |    std                  | 0.783      |
# |    value_loss           | 8.35       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 35          |
# |    time_elapsed         | 641         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.061161354 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.01        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00443    |
# |    std                  | 0.782       |
# |    value_loss           | 5.66        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 36         |
# |    time_elapsed         | 658        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.11907318 |
# |    clip_fraction        | 0.412      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.48      |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.502      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.00823    |
# |    std                  | 0.774      |
# |    value_loss           | 4.31       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 37          |
# |    time_elapsed         | 675         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.028078243 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00993     |
# |    std                  | 0.774       |
# |    value_loss           | 5.88        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 38         |
# |    time_elapsed         | 693        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.26926088 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.46      |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.107      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00766   |
# |    std                  | 0.775      |
# |    value_loss           | 5.1        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 39         |
# |    time_elapsed         | 709        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.06310429 |
# |    clip_fraction        | 0.35       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.46      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.668      |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.013      |
# |    std                  | 0.777      |
# |    value_loss           | 6.96       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 40          |
# |    time_elapsed         | 726         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.061157502 |
# |    clip_fraction        | 0.347       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.248       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0149      |
# |    std                  | 0.779       |
# |    value_loss           | 3.74        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 41          |
# |    time_elapsed         | 744         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.049606945 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00927     |
# |    std                  | 0.778       |
# |    value_loss           | 10.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 42          |
# |    time_elapsed         | 762         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.050235067 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.991       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00613     |
# |    std                  | 0.776       |
# |    value_loss           | 3.87        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 43          |
# |    time_elapsed         | 780         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.058851928 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.503       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0038     |
# |    std                  | 0.769       |
# |    value_loss           | 2.92        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 44         |
# |    time_elapsed         | 797        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.06326067 |
# |    clip_fraction        | 0.41       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.607      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.00203    |
# |    std                  | 0.765      |
# |    value_loss           | 4.2        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 113        |
# |    iterations           | 45         |
# |    time_elapsed         | 814        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.09176123 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.44      |
# |    explained_variance   | 0.978      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.127      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.0166     |
# |    std                  | 0.775      |
# |    value_loss           | 1.25       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 46          |
# |    time_elapsed         | 832         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.030216109 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.587       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00806     |
# |    std                  | 0.774       |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 47          |
# |    time_elapsed         | 851         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.041654922 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.37        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00437     |
# |    std                  | 0.769       |
# |    value_loss           | 2.96        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 113        |
# |    iterations           | 48         |
# |    time_elapsed         | 869        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.06609203 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.44      |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.09       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.00135    |
# |    std                  | 0.773      |
# |    value_loss           | 6.47       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 49          |
# |    time_elapsed         | 887         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.082359344 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.11        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00444     |
# |    std                  | 0.769       |
# |    value_loss           | 4.18        |
# -----------------------------------------

# %%
env = gym.make("CarRacing-v2", render_mode="human")
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 env = gym.make("CarRacing-v2", render_mode="human")
# ----> 2 evaluate_policy(model, env, n_eval_episodes=10, render=True)
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=86'>87</a> while (episode_counts < episode_count_targets).any():
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=87'>88</a>     actions, states = model.predict(
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=88'>89</a>         observations,  # type: ignore[arg-type]
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=89'>90</a>         state=states,
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=90'>91</a>         episode_start=episode_starts,
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=91'>92</a>         deterministic=deterministic,
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=92'>93</a>     )
# ---> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=93'>94</a>     new_observations, rewards, dones, infos = env.step(actions)
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=94'>95</a>     current_rewards += rewards
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py?line=95'>96</a>     current_lengths += 1
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:197, in VecEnv.step(self, actions)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=189'>190</a> """
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=190'>191</a> Step the environments with the given action
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=191'>192</a>
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=192'>193</a> :param actions: the action
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=193'>194</a> :return: observation, reward, done, information
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=194'>195</a> """
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=195'>196</a> self.step_async(actions)
# --> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=196'>197</a> return self.step_wait()
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=54'>55</a> def step_wait(self) -> VecEnvStepReturn:
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=55'>56</a>     # Avoid circular imports
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=56'>57</a>     for env_idx in range(self.num_envs):
# ---> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=57'>58</a>         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=58'>59</a>             self.actions[env_idx]
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=59'>60</a>         )
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=60'>61</a>         # convert to SB3 VecEnv api
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=61'>62</a>         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py?line=45'>46</a> def step(self, action):
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py?line=46'>47</a>     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py?line=47'>48</a>
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py?line=48'>49</a>     Args:
#    (...)
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py?line=54'>55</a>
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py?line=55'>56</a>     """
# ---> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py?line=56'>57</a>     observation, reward, terminated, truncated, info = self.env.step(action)
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py?line=57'>58</a>     self._elapsed_steps += 1
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/time_limit.py?line=59'>60</a>     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/order_enforcing.py?line=53'>54</a> if not self._has_reset:
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/order_enforcing.py?line=54'>55</a>     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/order_enforcing.py?line=55'>56</a> return self.env.step(action)
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/env_checker.py?line=48'>49</a>     return env_step_passive_checker(self.env, action)
#      <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/env_checker.py?line=49'>50</a> else:
# ---> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/wrappers/env_checker.py?line=50'>51</a>     return self.env.step(action)
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py:553, in CarRacing.step(self, action)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=549'>550</a> self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=550'>551</a> self.t += 1.0 / FPS
# --> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=552'>553</a> self.state = self._render("state_pixels")
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=554'>555</a> step_reward = 0
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=555'>556</a> terminated = False
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py:617, in CarRacing._render(self, mode)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=613'>614</a> trans = pygame.math.Vector2((scroll_x, scroll_y)).rotate_rad(angle)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=614'>615</a> trans = (WINDOW_W / 2 + trans[0], WINDOW_H / 4 + trans[1])
# --> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=616'>617</a> self._render_road(zoom, trans, angle)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=617'>618</a> self.car.draw(
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=618'>619</a>     self.surf,
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=619'>620</a>     zoom,
#    (...)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=622'>623</a>     mode not in ["state_pixels_list", "state_pixels"],
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=623'>624</a> )
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=625'>626</a> self.surf = pygame.transform.flip(self.surf, False, True)
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py:678, in CarRacing._render_road(self, zoom, translation, angle)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=668'>669</a>         grass.append(
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=669'>670</a>             [
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=670'>671</a>                 (GRASS_DIM * x + GRASS_DIM, GRASS_DIM * y + 0),
#    (...)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=674'>675</a>             ]
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=675'>676</a>         )
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=676'>677</a> for poly in grass:
# --> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=677'>678</a>     self._draw_colored_polygon(
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=678'>679</a>         self.surf, poly, self.grass_color, zoom, translation, angle
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=679'>680</a>     )
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=681'>682</a> # draw road
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=682'>683</a> for poly, color in self.road_poly:
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=683'>684</a>     # converting to pixel coordinates
#
# File ~/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py:774, in CarRacing._draw_colored_polygon(self, surface, poly, color, zoom, translation, angle, clip)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=763'>764</a> # This checks if the polygon is out of bounds of the screen, and we skip drawing if so.
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=764'>765</a> # Instead of calculating exactly if the polygon and screen overlap,
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=765'>766</a> # we simply check if the polygon is in a larger bounding box whose dimension
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=766'>767</a> # is greater than the screen by MAX_SHAPE_DIM, which is the maximum
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=767'>768</a> # diagonal length of an environment object
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=768'>769</a> if not clip or any(
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=769'>770</a>     (-MAX_SHAPE_DIM <= coord[0] <= WINDOW_W + MAX_SHAPE_DIM)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=770'>771</a>     and (-MAX_SHAPE_DIM <= coord[1] <= WINDOW_H + MAX_SHAPE_DIM)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=771'>772</a>     for coord in poly
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=772'>773</a> ):
# --> <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=773'>774</a>     gfxdraw.aapolygon(self.surf, poly, color)
#     <a href='file:///home/sawaiz/anaconda3/envs/rl/lib/python3.9/site-packages/gymnasium/envs/box2d/car_racing.py?line=774'>775</a>     gfxdraw.filled_polygon(self.surf, poly, color)
#
# KeyboardInterrupt:

# %%
# My observation is that it takes a really long time to train the models. Like 100000 timesteps which is a lot
# Secondly, why is the car getting stuck when it gets off track and why does it go off track?
# How can it come back? I remember reading in imitation learning that it is very difficult to get it back on track
# Also the reward function for it is weird. Why shape it like that?
